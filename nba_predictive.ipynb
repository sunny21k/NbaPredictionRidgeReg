# %%
import pandas as pd

# %%
df = pd.read_csv("nba_games.csv", index_col=0)

# %%
df
# Out:
#          mp   mp.1    fg    fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0     240.0  240.0  38.0   72.0  0.528  16.0  37.0  0.432  18.0  21.0  ...
# 1     240.0  240.0  40.0   84.0  0.476  14.0  39.0  0.359  13.0  15.0  ...
# 2     240.0  240.0  37.0   87.0  0.425   7.0  33.0  0.212  32.0  35.0  ...
# 3     240.0  240.0  47.0  106.0  0.443  12.0  43.0  0.279  20.0  24.0  ...
# 4     240.0  240.0  42.0   79.0  0.532  14.0  35.0  0.400  20.0  26.0  ...
# ...     ...    ...   ...    ...    ...   ...   ...    ...   ...   ...  ...
# 7281  240.0  240.0  38.0   82.0  0.463  12.0  37.0  0.324  15.0  18.0  ...
# 7282  240.0  240.0  34.0   95.0  0.358   7.0  33.0  0.212  17.0  23.0  ...
# 7283  240.0  240.0  35.0   81.0  0.432  11.0  26.0  0.423  27.0  36.0  ...
# 7284  240.0  240.0  41.0   85.0  0.482   9.0  26.0  0.346  26.0  30.0  ...
# 7285  240.0  240.0  33.0   85.0  0.388  12.0  44.0  0.273  28.0  34.0  ...
#
#       tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0             26.2          26.8         155.0         123.0       MIA
# 1             41.0          37.3         160.0         121.0       POR
# 2             20.0          32.3         226.0         117.0       TOR
# 3             25.8          30.7         168.0         127.0       LAL
# 4             20.0          33.6         245.0         125.0       UTA
# ...            ...           ...           ...           ...       ...
# 7281          60.0          29.8         159.0         115.0       MEM
# 7282          59.2          34.5         231.0         103.0       LAC
# 7283          34.2          33.7         160.0         118.0       OKC
# 7284          27.7          27.1         150.0         126.0       MIA
# 7285          51.5          36.2         141.0         114.0       BOS
#
#       total_opp  home_opp  season        date    won
# 0           107         1    2023  2022-11-07   True
# 1           110         0    2023  2022-11-07  False
# 2           126         1    2023  2022-12-07  False
# 3           113         0    2023  2022-12-07   True
# 4           108         1    2023  2022-12-09   True
# ...         ...       ...     ...         ...    ...
# 7281        112         0    2017  2017-02-13  False
# 7282        108         1    2019  2018-10-19  False
# 7283         92         0    2019  2018-10-19   True
# 7284        106         1    2020  2020-09-19   True
# 7285        117         0    2020  2020-09-19  False
#
# [7286 rows x 154 columns]

# %%
df = df.sort_values("date")
df
# Out:
#          mp   mp.1    fg   fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 4602  240.0  240.0  32.0  87.0  0.368   9.0  27.0  0.333  15.0  20.0  ...
# 4603  240.0  240.0  45.0  94.0  0.479  13.0  35.0  0.371  14.0  19.0  ...
# 6370  240.0  240.0  40.0  82.0  0.488   8.0  24.0  0.333  16.0  16.0  ...
# 4155  240.0  240.0  40.0  85.0  0.471   7.0  33.0  0.212  13.0  18.0  ...
# 4154  240.0  240.0  47.0  98.0  0.480  12.0  24.0  0.500  23.0  26.0  ...
# ...     ...    ...   ...   ...    ...   ...   ...    ...   ...   ...  ...
# 6108  240.0  240.0  40.0  78.0  0.513   9.0  23.0  0.391   8.0  10.0  ...
# 3789  240.0  240.0  33.0  93.0  0.355  14.0  30.0  0.467  23.0  29.0  ...
# 3788  240.0  240.0  34.0  78.0  0.436   7.0  35.0  0.200  29.0  34.0  ...
# 4580  240.0  240.0  42.0  86.0  0.488  14.0  28.0  0.500   5.0   6.0  ...
# 4581  240.0  240.0  32.0  82.0  0.390   9.0  42.0  0.214  11.0  13.0  ...
#
#       tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 4602          66.7          36.8         200.0         101.0       CLE
# 4603          50.0          36.8         153.0         125.0       NYK
# 6370          50.0          39.2         220.0         120.0       POR
# 4155         100.0          36.2         263.0         112.0       SAS
# 4154          75.0          31.8         139.0         143.0       GSW
# ...            ...           ...           ...           ...       ...
# 6108          33.3          59.8         205.0         126.0       BOS
# 3789          19.3          32.9         164.0         129.0       BOS
# 3788          12.7          27.1         138.0         124.0       MIA
# 4580          25.1          35.6         264.0         121.0       BOS
# 4581          33.3          32.9         154.0         103.0       MIA
#
#       total_opp  home_opp  season        date    won
# 4602        117         1    2017  2016-10-25  False
# 4603         88         0    2017  2016-10-25   True
# 6370        113         1    2017  2016-10-25  False
# 4155        129         0    2017  2016-10-25  False
# 4154        100         1    2017  2016-10-25   True
# ...         ...       ...     ...         ...    ...
# 6108        110         1    2023  2023-05-25  False
# 3789        104         0    2023  2023-05-27  False
# 3788        103         1    2023  2023-05-27   True
# 4580         84         1    2023  2023-05-29   True
# 4581        103         0    2023  2023-05-29  False
#
# [7286 rows x 154 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#          mp   mp.1    fg   fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0     240.0  240.0  32.0  87.0  0.368   9.0  27.0  0.333  15.0  20.0  ...
# 1     240.0  240.0  45.0  94.0  0.479  13.0  35.0  0.371  14.0  19.0  ...
# 2     240.0  240.0  40.0  82.0  0.488   8.0  24.0  0.333  16.0  16.0  ...
# 3     240.0  240.0  40.0  85.0  0.471   7.0  33.0  0.212  13.0  18.0  ...
# 4     240.0  240.0  47.0  98.0  0.480  12.0  24.0  0.500  23.0  26.0  ...
# ...     ...    ...   ...   ...    ...   ...   ...    ...   ...   ...  ...
# 7281  240.0  240.0  40.0  78.0  0.513   9.0  23.0  0.391   8.0  10.0  ...
# 7282  240.0  240.0  33.0  93.0  0.355  14.0  30.0  0.467  23.0  29.0  ...
# 7283  240.0  240.0  34.0  78.0  0.436   7.0  35.0  0.200  29.0  34.0  ...
# 7284  240.0  240.0  42.0  86.0  0.488  14.0  28.0  0.500   5.0   6.0  ...
# 7285  240.0  240.0  32.0  82.0  0.390   9.0  42.0  0.214  11.0  13.0  ...
#
#       tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0             66.7          36.8         200.0         101.0       CLE
# 1             50.0          36.8         153.0         125.0       NYK
# 2             50.0          39.2         220.0         120.0       POR
# 3            100.0          36.2         263.0         112.0       SAS
# 4             75.0          31.8         139.0         143.0       GSW
# ...            ...           ...           ...           ...       ...
# 7281          33.3          59.8         205.0         126.0       BOS
# 7282          19.3          32.9         164.0         129.0       BOS
# 7283          12.7          27.1         138.0         124.0       MIA
# 7284          25.1          35.6         264.0         121.0       BOS
# 7285          33.3          32.9         154.0         103.0       MIA
#
#       total_opp  home_opp  season        date    won
# 0           117         1    2017  2016-10-25  False
# 1            88         0    2017  2016-10-25   True
# 2           113         1    2017  2016-10-25  False
# 3           129         0    2017  2016-10-25  False
# 4           100         1    2017  2016-10-25   True
# ...         ...       ...     ...         ...    ...
# 7281        110         1    2023  2023-05-25  False
# 7282        104         0    2023  2023-05-27  False
# 7283        103         1    2023  2023-05-27   True
# 7284         84         1    2023  2023-05-29   True
# 7285        103         0    2023  2023-05-29  False
#
# [7286 rows x 154 columns]

# %%
del df["mp_opp.1"]
del df["index_opp"]

# %%
df
# Out:
#          mp   mp.1    fg   fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0     240.0  240.0  32.0  87.0  0.368   9.0  27.0  0.333  15.0  20.0  ...
# 1     240.0  240.0  45.0  94.0  0.479  13.0  35.0  0.371  14.0  19.0  ...
# 2     240.0  240.0  40.0  82.0  0.488   8.0  24.0  0.333  16.0  16.0  ...
# 3     240.0  240.0  40.0  85.0  0.471   7.0  33.0  0.212  13.0  18.0  ...
# 4     240.0  240.0  47.0  98.0  0.480  12.0  24.0  0.500  23.0  26.0  ...
# ...     ...    ...   ...   ...    ...   ...   ...    ...   ...   ...  ...
# 7281  240.0  240.0  40.0  78.0  0.513   9.0  23.0  0.391   8.0  10.0  ...
# 7282  240.0  240.0  33.0  93.0  0.355  14.0  30.0  0.467  23.0  29.0  ...
# 7283  240.0  240.0  34.0  78.0  0.436   7.0  35.0  0.200  29.0  34.0  ...
# 7284  240.0  240.0  42.0  86.0  0.488  14.0  28.0  0.500   5.0   6.0  ...
# 7285  240.0  240.0  32.0  82.0  0.390   9.0  42.0  0.214  11.0  13.0  ...
#
#       tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0             66.7          36.8         200.0         101.0       CLE
# 1             50.0          36.8         153.0         125.0       NYK
# 2             50.0          39.2         220.0         120.0       POR
# 3            100.0          36.2         263.0         112.0       SAS
# 4             75.0          31.8         139.0         143.0       GSW
# ...            ...           ...           ...           ...       ...
# 7281          33.3          59.8         205.0         126.0       BOS
# 7282          19.3          32.9         164.0         129.0       BOS
# 7283          12.7          27.1         138.0         124.0       MIA
# 7284          25.1          35.6         264.0         121.0       BOS
# 7285          33.3          32.9         154.0         103.0       MIA
#
#       total_opp  home_opp  season        date    won
# 0           117         1    2017  2016-10-25  False
# 1            88         0    2017  2016-10-25   True
# 2           113         1    2017  2016-10-25  False
# 3           129         0    2017  2016-10-25  False
# 4           100         1    2017  2016-10-25   True
# ...         ...       ...     ...         ...    ...
# 7281        110         1    2023  2023-05-25  False
# 7282        104         0    2023  2023-05-27  False
# 7283        103         1    2023  2023-05-27   True
# 7284         84         1    2023  2023-05-29   True
# 7285        103         0    2023  2023-05-29  False
#
# [7286 rows x 152 columns]

# %%
def add_target(team):
    team["target"] = team["won"].shift(-1)
    return team

df = df.groupby("team", group_keys=False).apply(add_target)
# Out:
# /var/folders/jn/kjpxydnn7mv7lk9_v6glkk_h0000gn/T/ipykernel_35107/1127067056.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("team", group_keys=False).apply(add_target)

# %%
df[df["team"] == "WAS"]
# Out:
#          mp   mp.1    fg   fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 29    240.0  240.0  40.0  94.0  0.426   6.0  20.0  0.300  13.0  18.0  ...
# 70    265.0  265.0  38.0  86.0  0.442   5.0  25.0  0.200  22.0  25.0  ...
# 120   240.0  240.0  44.0  96.0  0.458  12.0  33.0  0.364  16.0  21.0  ...
# 148   240.0  240.0  38.0  83.0  0.458  10.0  31.0  0.323  19.0  22.0  ...
# 185   265.0  265.0  50.0  99.0  0.505  12.0  29.0  0.414  23.0  26.0  ...
# ...     ...    ...   ...   ...    ...   ...   ...    ...   ...   ...  ...
# 7003  240.0  240.0  39.0  79.0  0.494  16.0  37.0  0.432  15.0  18.0  ...
# 7007  240.0  240.0  50.0  99.0  0.505  13.0  27.0  0.481  15.0  21.0  ...
# 7046  240.0  240.0  45.0  94.0  0.479   6.0  28.0  0.214  20.0  26.0  ...
# 7063  240.0  240.0  39.0  84.0  0.464   7.0  33.0  0.212  29.0  37.0  ...
# 7089  240.0  240.0  41.0  97.0  0.423  14.0  45.0  0.311  13.0  21.0  ...
#
#       usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  home_opp  \
# 29            31.7         200.0         106.0       ATL        114         1
# 70            39.2         221.0         111.0       MEM        112         1
# 120           36.8         156.0         123.0       LAL        108         0
# 148           34.0         154.0         116.0       NOP         91         0
# 185           28.2         166.0         129.0       CLE        140         0
# ...            ...           ...           ...       ...        ...       ...
# 7003          31.2         192.0         120.0       NYK        118         1
# 7007          37.5         208.0         126.0       MIL        140         0
# 7046          40.6         206.0         121.0       ATL        134         1
# 7063          44.5         149.0         117.0       MIA        108         0
# 7089          27.3         136.0         117.0       HOU        114         0
#
#       season        date    won  target
# 29      2017  2016-10-27  False   False
# 70      2017  2016-10-30  False    True
# 120     2017  2017-02-02   True    True
# 148     2017  2017-02-04   True   False
# 185     2017  2017-02-06  False    True
# ...      ...         ...    ...     ...
# 7003    2023  2023-04-02  False   False
# 7007    2023  2023-04-04  False   False
# 7046    2023  2023-04-05  False    True
# 7063    2023  2023-04-07   True   False
# 7089    2023  2023-04-09  False     NaN
#
# [225 rows x 153 columns]

# %%
df["team"]
# Out:
# 0       NYK
# 1       CLE
# 2       UTA
# 3       GSW
# 4       SAS
#        ...
# 7281    MIA
# 7282    MIA
# 7283    BOS
# 7284    MIA
# 7285    BOS
# Name: team, Length: 7286, dtype: object

# %%
df["target"][pd.isnull(df["target"])] = 2
# Out:
# /var/folders/jn/kjpxydnn7mv7lk9_v6glkk_h0000gn/T/ipykernel_35107/1618397414.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["target"][pd.isnull(df["target"])] = 2
# /var/folders/jn/kjpxydnn7mv7lk9_v6glkk_h0000gn/T/ipykernel_35107/1618397414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["target"][pd.isnull(df["target"])] = 2

# %%
df["target"] = df["target"].astype(int, errors="ignore")

# %%
df
# Out:
#          mp   mp.1    fg   fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0     240.0  240.0  32.0  87.0  0.368   9.0  27.0  0.333  15.0  20.0  ...
# 1     240.0  240.0  45.0  94.0  0.479  13.0  35.0  0.371  14.0  19.0  ...
# 2     240.0  240.0  40.0  82.0  0.488   8.0  24.0  0.333  16.0  16.0  ...
# 3     240.0  240.0  40.0  85.0  0.471   7.0  33.0  0.212  13.0  18.0  ...
# 4     240.0  240.0  47.0  98.0  0.480  12.0  24.0  0.500  23.0  26.0  ...
# ...     ...    ...   ...   ...    ...   ...   ...    ...   ...   ...  ...
# 7281  240.0  240.0  40.0  78.0  0.513   9.0  23.0  0.391   8.0  10.0  ...
# 7282  240.0  240.0  33.0  93.0  0.355  14.0  30.0  0.467  23.0  29.0  ...
# 7283  240.0  240.0  34.0  78.0  0.436   7.0  35.0  0.200  29.0  34.0  ...
# 7284  240.0  240.0  42.0  86.0  0.488  14.0  28.0  0.500   5.0   6.0  ...
# 7285  240.0  240.0  32.0  82.0  0.390   9.0  42.0  0.214  11.0  13.0  ...
#
#       usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  home_opp  \
# 0             36.8         200.0         101.0       CLE        117         1
# 1             36.8         153.0         125.0       NYK         88         0
# 2             39.2         220.0         120.0       POR        113         1
# 3             36.2         263.0         112.0       SAS        129         0
# 4             31.8         139.0         143.0       GSW        100         1
# ...            ...           ...           ...       ...        ...       ...
# 7281          59.8         205.0         126.0       BOS        110         1
# 7282          32.9         164.0         129.0       BOS        104         0
# 7283          27.1         138.0         124.0       MIA        103         1
# 7284          35.6         264.0         121.0       BOS         84         1
# 7285          32.9         154.0         103.0       MIA        103         0
#
#       season        date    won  target
# 0       2017  2016-10-25  False       1
# 1       2017  2016-10-25   True       1
# 2       2017  2016-10-25  False       1
# 3       2017  2016-10-25  False       1
# 4       2017  2016-10-25   True       1
# ...      ...         ...    ...     ...
# 7281    2023  2023-05-25  False       0
# 7282    2023  2023-05-27  False       1
# 7283    2023  2023-05-27   True       0
# 7284    2023  2023-05-29   True       2
# 7285    2023  2023-05-29  False       2
#
# [7286 rows x 153 columns]

# %%
df["won"].value_counts()
# Out:
# won
# False    3643
# True     3643
# Name: count, dtype: int64

# %%
df["target"].value_counts()
# Out:
# target
# 0    3629
# 1    3627
# 2      30
# Name: count, dtype: int64

# %%
nulls = pd.isnull(df)

# %%
nulls = nulls.sum()

# %%
nulls = nulls[nulls > 0]

# %%
valid_columns = df.columns[~df.columns.isin(nulls.index)]

# %%
valid_columns
# Out:
# Index(['mp', 'mp.1', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta',
#        ...
#        'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp', 'team_opp', 'total_opp',
#        'home_opp', 'season', 'date', 'won', 'target'],
#       dtype='object', length=145)

# %%
df = df[valid_columns].copy()

# %%
df
# Out:
#          mp   mp.1    fg   fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0     240.0  240.0  32.0  87.0  0.368   9.0  27.0  0.333  15.0  20.0  ...
# 1     240.0  240.0  45.0  94.0  0.479  13.0  35.0  0.371  14.0  19.0  ...
# 2     240.0  240.0  40.0  82.0  0.488   8.0  24.0  0.333  16.0  16.0  ...
# 3     240.0  240.0  40.0  85.0  0.471   7.0  33.0  0.212  13.0  18.0  ...
# 4     240.0  240.0  47.0  98.0  0.480  12.0  24.0  0.500  23.0  26.0  ...
# ...     ...    ...   ...   ...    ...   ...   ...    ...   ...   ...  ...
# 7281  240.0  240.0  40.0  78.0  0.513   9.0  23.0  0.391   8.0  10.0  ...
# 7282  240.0  240.0  33.0  93.0  0.355  14.0  30.0  0.467  23.0  29.0  ...
# 7283  240.0  240.0  34.0  78.0  0.436   7.0  35.0  0.200  29.0  34.0  ...
# 7284  240.0  240.0  42.0  86.0  0.488  14.0  28.0  0.500   5.0   6.0  ...
# 7285  240.0  240.0  32.0  82.0  0.390   9.0  42.0  0.214  11.0  13.0  ...
#
#       usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  home_opp  \
# 0             36.8         200.0         101.0       CLE        117         1
# 1             36.8         153.0         125.0       NYK         88         0
# 2             39.2         220.0         120.0       POR        113         1
# 3             36.2         263.0         112.0       SAS        129         0
# 4             31.8         139.0         143.0       GSW        100         1
# ...            ...           ...           ...       ...        ...       ...
# 7281          59.8         205.0         126.0       BOS        110         1
# 7282          32.9         164.0         129.0       BOS        104         0
# 7283          27.1         138.0         124.0       MIA        103         1
# 7284          35.6         264.0         121.0       BOS         84         1
# 7285          32.9         154.0         103.0       MIA        103         0
#
#       season        date    won  target
# 0       2017  2016-10-25  False       1
# 1       2017  2016-10-25   True       1
# 2       2017  2016-10-25  False       1
# 3       2017  2016-10-25  False       1
# 4       2017  2016-10-25   True       1
# ...      ...         ...    ...     ...
# 7281    2023  2023-05-25  False       0
# 7282    2023  2023-05-27  False       1
# 7283    2023  2023-05-27   True       0
# 7284    2023  2023-05-29   True       2
# 7285    2023  2023-05-29  False       2
#
# [7286 rows x 145 columns]

# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.12/site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import RidgeClassifier

rr = RidgeClassifier(alpha=1)
split = TimeSeriesSplit(n_splits = 3)

sfs = SequentialFeatureSelector(rr, n_features_to_select=30, direction="forward", cv=split)

# %%
removed_columns = ["season", "date", "won", "target", "team", "team_opp"]

# %%
selected_columns = df.columns[~df.columns.isin(removed_columns)]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[selected_columns] = scaler.fit_transform(df[selected_columns])

# %%
df
# Out:
#        mp  mp.1        fg       fga       fg%        3p       3pa       3p%  \
# 0     0.0   0.0  0.261905  0.413793  0.236842  0.285714  0.307692  0.399135
# 1     0.0   0.0  0.571429  0.534483  0.502392  0.428571  0.461538  0.453890
# 2     0.0   0.0  0.452381  0.327586  0.523923  0.250000  0.250000  0.399135
# 3     0.0   0.0  0.452381  0.379310  0.483254  0.214286  0.423077  0.224784
# 4     0.0   0.0  0.619048  0.603448  0.504785  0.392857  0.250000  0.639769
# ...   ...   ...       ...       ...       ...       ...       ...       ...
# 7281  0.0   0.0  0.452381  0.258621  0.583732  0.285714  0.230769  0.482709
# 7282  0.0   0.0  0.285714  0.517241  0.205742  0.464286  0.365385  0.592219
# 7283  0.0   0.0  0.309524  0.258621  0.399522  0.214286  0.461538  0.207493
# 7284  0.0   0.0  0.500000  0.396552  0.523923  0.464286  0.326923  0.639769
# 7285  0.0   0.0  0.261905  0.327586  0.289474  0.285714  0.596154  0.227666
#
#             ft       fta  ...  usg%_max_opp  ortg_max_opp  drtg_max_opp  \
# 0     0.333333  0.372549  ...      0.189744      0.502488      0.256098
# 1     0.309524  0.352941  ...      0.189744      0.268657      0.548780
# 2     0.357143  0.294118  ...      0.220513      0.601990      0.487805
# 3     0.285714  0.333333  ...      0.182051      0.815920      0.390244
# 4     0.523810  0.490196  ...      0.125641      0.199005      0.768293
# ...        ...       ...  ...           ...           ...           ...
# 7281  0.166667  0.176471  ...      0.484615      0.527363      0.560976
# 7282  0.523810  0.549020  ...      0.139744      0.323383      0.597561
# 7283  0.666667  0.647059  ...      0.065385      0.194030      0.536585
# 7284  0.095238  0.098039  ...      0.174359      0.820896      0.500000
# 7285  0.238095  0.235294  ...      0.139744      0.273632      0.280488
#
#       team_opp  total_opp  home_opp  season        date    won  target
# 0          CLE   0.523256       1.0    2017  2016-10-25  False       1
# 1          NYK   0.186047       0.0    2017  2016-10-25   True       1
# 2          POR   0.476744       1.0    2017  2016-10-25  False       1
# 3          SAS   0.662791       0.0    2017  2016-10-25  False       1
# 4          GSW   0.325581       1.0    2017  2016-10-25   True       1
# ...        ...        ...       ...     ...         ...    ...     ...
# 7281       BOS   0.441860       1.0    2023  2023-05-25  False       0
# 7282       BOS   0.372093       0.0    2023  2023-05-27  False       1
# 7283       MIA   0.360465       1.0    2023  2023-05-27   True       0
# 7284       BOS   0.139535       1.0    2023  2023-05-29   True       2
# 7285       MIA   0.360465       0.0    2023  2023-05-29  False       2
#
# [7286 rows x 145 columns]

# %%
sfs.fit(df[selected_columns], df["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['mp',
#  'mp.1',
#  '3p',
#  'fta',
#  'trb',
#  'ast',
#  'pf',
#  'tov%',
#  'usg%',
#  'blk_max',
#  'pf_max',
#  '+/-_max',
#  'blk%_max',
#  'tov%_max',
#  'mp_opp',
#  '3p%_opp',
#  'fta_opp',
#  'ftr_opp',
#  'ast%_opp',
#  'blk%_opp',
#  'usg%_opp',
#  '3p_max_opp',
#  'ft_max_opp',
#  'orb_max_opp',
#  'drb_max_opp',
#  'trb_max_opp',
#  'tov_max_opp',
#  'drb%_max_opp',
#  'blk%_max_opp',
#  'ortg_max_opp']

# %%
def backtest(data, model, predictors, start=2, step=1):
    all_predictions = []
    
    seasons = sorted(data["season"].unique())
    
    for i in range(start, len(seasons), step):
        season = seasons[i]
        train = data[data["season"] < season]
        test = data[data["season"] == season]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(df, rr, predictors)

# %%
predictions
# Out:
#       actual  prediction
# 1444       1           0
# 1445       0           1
# 1446       1           0
# 1447       0           1
# 1448       1           0
# ...      ...         ...
# 7281       0           0
# 7282       1           0
# 7283       0           0
# 7284       2           1
# 7285       2           1
#
# [5842 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score

predictions = predictions[predictions["actual"] != 2]
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.5363041982105987

# %%
df.groupby("home").apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0])
# Out:
# /var/folders/jn/kjpxydnn7mv7lk9_v6glkk_h0000gn/T/ipykernel_35107/3128703651.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby("home").apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0])
# home
# 0.0    0.4381
# 1.0    0.5619
# dtype: float64

# %%
df
# Out:
#        mp  mp.1        fg       fga       fg%        3p       3pa       3p%  \
# 0     0.0   0.0  0.261905  0.413793  0.236842  0.285714  0.307692  0.399135
# 1     0.0   0.0  0.571429  0.534483  0.502392  0.428571  0.461538  0.453890
# 2     0.0   0.0  0.452381  0.327586  0.523923  0.250000  0.250000  0.399135
# 3     0.0   0.0  0.452381  0.379310  0.483254  0.214286  0.423077  0.224784
# 4     0.0   0.0  0.619048  0.603448  0.504785  0.392857  0.250000  0.639769
# ...   ...   ...       ...       ...       ...       ...       ...       ...
# 7281  0.0   0.0  0.452381  0.258621  0.583732  0.285714  0.230769  0.482709
# 7282  0.0   0.0  0.285714  0.517241  0.205742  0.464286  0.365385  0.592219
# 7283  0.0   0.0  0.309524  0.258621  0.399522  0.214286  0.461538  0.207493
# 7284  0.0   0.0  0.500000  0.396552  0.523923  0.464286  0.326923  0.639769
# 7285  0.0   0.0  0.261905  0.327586  0.289474  0.285714  0.596154  0.227666
#
#             ft       fta  ...  usg%_max_opp  ortg_max_opp  drtg_max_opp  \
# 0     0.333333  0.372549  ...      0.189744      0.502488      0.256098
# 1     0.309524  0.352941  ...      0.189744      0.268657      0.548780
# 2     0.357143  0.294118  ...      0.220513      0.601990      0.487805
# 3     0.285714  0.333333  ...      0.182051      0.815920      0.390244
# 4     0.523810  0.490196  ...      0.125641      0.199005      0.768293
# ...        ...       ...  ...           ...           ...           ...
# 7281  0.166667  0.176471  ...      0.484615      0.527363      0.560976
# 7282  0.523810  0.549020  ...      0.139744      0.323383      0.597561
# 7283  0.666667  0.647059  ...      0.065385      0.194030      0.536585
# 7284  0.095238  0.098039  ...      0.174359      0.820896      0.500000
# 7285  0.238095  0.235294  ...      0.139744      0.273632      0.280488
#
#       team_opp  total_opp  home_opp  season        date    won  target
# 0          CLE   0.523256       1.0    2017  2016-10-25  False       1
# 1          NYK   0.186047       0.0    2017  2016-10-25   True       1
# 2          POR   0.476744       1.0    2017  2016-10-25  False       1
# 3          SAS   0.662791       0.0    2017  2016-10-25  False       1
# 4          GSW   0.325581       1.0    2017  2016-10-25   True       1
# ...        ...        ...       ...     ...         ...    ...     ...
# 7281       BOS   0.441860       1.0    2023  2023-05-25  False       0
# 7282       BOS   0.372093       0.0    2023  2023-05-27  False       1
# 7283       MIA   0.360465       1.0    2023  2023-05-27   True       0
# 7284       BOS   0.139535       1.0    2023  2023-05-29   True       2
# 7285       MIA   0.360465       0.0    2023  2023-05-29  False       2
#
# [7286 rows x 145 columns]

# %%
df_rolling = df[list(selected_columns) + ["won", "team", "season"]]

# %%
df_rolling
# Out:
#        mp  mp.1        fg       fga       fg%        3p       3pa       3p%  \
# 0     0.0   0.0  0.261905  0.413793  0.236842  0.285714  0.307692  0.399135
# 1     0.0   0.0  0.571429  0.534483  0.502392  0.428571  0.461538  0.453890
# 2     0.0   0.0  0.452381  0.327586  0.523923  0.250000  0.250000  0.399135
# 3     0.0   0.0  0.452381  0.379310  0.483254  0.214286  0.423077  0.224784
# 4     0.0   0.0  0.619048  0.603448  0.504785  0.392857  0.250000  0.639769
# ...   ...   ...       ...       ...       ...       ...       ...       ...
# 7281  0.0   0.0  0.452381  0.258621  0.583732  0.285714  0.230769  0.482709
# 7282  0.0   0.0  0.285714  0.517241  0.205742  0.464286  0.365385  0.592219
# 7283  0.0   0.0  0.309524  0.258621  0.399522  0.214286  0.461538  0.207493
# 7284  0.0   0.0  0.500000  0.396552  0.523923  0.464286  0.326923  0.639769
# 7285  0.0   0.0  0.261905  0.327586  0.289474  0.285714  0.596154  0.227666
#
#             ft       fta  ...  blk%_max_opp  tov%_max_opp  usg%_max_opp  \
# 0     0.333333  0.372549  ...         0.144      0.644610      0.189744
# 1     0.309524  0.352941  ...         0.106      0.466382      0.189744
# 2     0.357143  0.294118  ...         0.051      0.466382      0.220513
# 3     0.285714  0.333333  ...         0.111      1.000000      0.182051
# 4     0.523810  0.490196  ...         0.072      0.733191      0.125641
# ...        ...       ...  ...           ...           ...           ...
# 7281  0.166667  0.176471  ...         0.262      0.288154      0.484615
# 7282  0.523810  0.549020  ...         0.054      0.138741      0.139744
# 7283  0.666667  0.647059  ...         0.062      0.068303      0.065385
# 7284  0.095238  0.098039  ...         0.117      0.200640      0.174359
# 7285  0.238095  0.235294  ...         0.060      0.288154      0.139744
#
#       ortg_max_opp  drtg_max_opp  total_opp  home_opp    won  team  season
# 0         0.502488      0.256098   0.523256       1.0  False   NYK    2017
# 1         0.268657      0.548780   0.186047       0.0   True   CLE    2017
# 2         0.601990      0.487805   0.476744       1.0  False   UTA    2017
# 3         0.815920      0.390244   0.662791       0.0  False   GSW    2017
# 4         0.199005      0.768293   0.325581       1.0   True   SAS    2017
# ...            ...           ...        ...       ...    ...   ...     ...
# 7281      0.527363      0.560976   0.441860       1.0  False   MIA    2023
# 7282      0.323383      0.597561   0.372093       0.0  False   MIA    2023
# 7283      0.194030      0.536585   0.360465       1.0   True   BOS    2023
# 7284      0.820896      0.500000   0.139535       1.0   True   MIA    2023
# 7285      0.273632      0.280488   0.360465       0.0  False   BOS    2023
#
# [7286 rows x 142 columns]

# %%
df_rolling = df[list(selected_columns) + ["won", "team", "season"]]

def find_team_averages(team):
    rolling = team.rolling(10).mean()
    return rolling

df_rolling = df_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_averages)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/window/rolling.py:371, in BaseWindow._prep_values(self, values)
#     370     else:
# --> 371         values = ensure_float64(values)
#     372 except (ValueError, TypeError) as err:
#
# File pandas/_libs/algos_common_helper.pxi:42, in pandas._libs.algos.ensure_float64()
#
# ValueError: could not convert string to float: 'ATL'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/window/rolling.py:489, in BaseWindow._apply_columnwise(self, homogeneous_func, name, numeric_only)
#     488 try:
# --> 489     arr = self._prep_values(arr)
#     490 except (TypeError, NotImplementedError) as err:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/window/rolling.py:373, in BaseWindow._prep_values(self, values)
#     372 except (ValueError, TypeError) as err:
# --> 373     raise TypeError(f"cannot handle this type -> {values.dtype}") from err
#     375 # Convert inf to nan for C funcs
#
# TypeError: cannot handle this type -> object
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# Cell In[333], line 7
#       4     rolling = team.rolling(10).mean()
#       5     return rolling
# ----> 7 df_rolling = df_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_averages)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1824, in GroupBy.apply(self, func, include_groups, *args, **kwargs)
#    1822 with option_context("mode.chained_assignment", None):
#    1823     try:
# -> 1824         result = self._python_apply_general(f, self._selected_obj)
#    1825         if (
#    1826             not isinstance(self.obj, Series)
#    1827             and self._selection is None
#    1828             and self._selected_obj.shape != self._obj_with_exclusions.shape
#    1829         ):
#    1830             warnings.warn(
#    1831                 message=_apply_groupings_depr.format(
#    1832                     type(self).__name__, "apply"
#    (...)
#    1835                 stacklevel=find_stack_level(),
#    1836             )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1885, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1850 @final
#    1851 def _python_apply_general(
#    1852     self,
#    (...)
#    1857     is_agg: bool = False,
#    1858 ) -> NDFrameT:
#    1859     """
#    1860     Apply function f in python space
#    1861
#    (...)
#    1883         data after applying f
#    1884     """
# -> 1885     values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#    1886     if not_indexed_same is None:
#    1887         not_indexed_same = mutated
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/groupby/ops.py:919, in BaseGrouper.apply_groupwise(self, f, data, axis)
#     917 # group might be modified
#     918 group_axes = group.axes
# --> 919 res = f(group)
#     920 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     921     mutated = True
#
# Cell In[333], line 4, in find_team_averages(team)
#       3 def find_team_averages(team):
# ----> 4     rolling = team.rolling(10).mean()
#       5     return rolling
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/window/rolling.py:2259, in Rolling.mean(self, numeric_only, engine, engine_kwargs)
#    2216 @doc(
#    2217     template_header,
#    2218     create_section_header("Parameters"),
#    (...)
#    2257     engine_kwargs: dict[str, bool] | None = None,
#    2258 ):
# -> 2259     return super().mean(
#    2260         numeric_only=numeric_only,
#    2261         engine=engine,
#    2262         engine_kwargs=engine_kwargs,
#    2263     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/window/rolling.py:1625, in RollingAndExpandingMixin.mean(self, numeric_only, engine, engine_kwargs)
#    1623         return self._numba_apply(sliding_mean, engine_kwargs)
#    1624 window_func = window_aggregations.roll_mean
# -> 1625 return self._apply(window_func, name="mean", numeric_only=numeric_only)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/window/rolling.py:619, in BaseWindow._apply(self, func, name, numeric_only, numba_args, **kwargs)
#     616     return result
#     618 if self.method == "single":
# --> 619     return self._apply_columnwise(homogeneous_func, name, numeric_only)
#     620 else:
#     621     return self._apply_tablewise(homogeneous_func, name, numeric_only)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/window/rolling.py:491, in BaseWindow._apply_columnwise(self, homogeneous_func, name, numeric_only)
#     489     arr = self._prep_values(arr)
#     490 except (TypeError, NotImplementedError) as err:
# --> 491     raise DataError(
#     492         f"Cannot aggregate non-numeric type: {arr.dtype}"
#     493     ) from err
#     494 res = homogeneous_func(arr)
#     495 res_values.append(res)
#
# DataError: Cannot aggregate non-numeric type: object

# %%
df_rolling
# Out:
#        mp  mp.1        fg       fga       fg%        3p       3pa       3p%  \
# 0     0.0   0.0  0.261905  0.413793  0.236842  0.285714  0.307692  0.399135
# 1     0.0   0.0  0.571429  0.534483  0.502392  0.428571  0.461538  0.453890
# 2     0.0   0.0  0.452381  0.327586  0.523923  0.250000  0.250000  0.399135
# 3     0.0   0.0  0.452381  0.379310  0.483254  0.214286  0.423077  0.224784
# 4     0.0   0.0  0.619048  0.603448  0.504785  0.392857  0.250000  0.639769
# ...   ...   ...       ...       ...       ...       ...       ...       ...
# 7281  0.0   0.0  0.452381  0.258621  0.583732  0.285714  0.230769  0.482709
# 7282  0.0   0.0  0.285714  0.517241  0.205742  0.464286  0.365385  0.592219
# 7283  0.0   0.0  0.309524  0.258621  0.399522  0.214286  0.461538  0.207493
# 7284  0.0   0.0  0.500000  0.396552  0.523923  0.464286  0.326923  0.639769
# 7285  0.0   0.0  0.261905  0.327586  0.289474  0.285714  0.596154  0.227666
#
#             ft       fta  ...  blk%_max_opp  tov%_max_opp  usg%_max_opp  \
# 0     0.333333  0.372549  ...         0.144      0.644610      0.189744
# 1     0.309524  0.352941  ...         0.106      0.466382      0.189744
# 2     0.357143  0.294118  ...         0.051      0.466382      0.220513
# 3     0.285714  0.333333  ...         0.111      1.000000      0.182051
# 4     0.523810  0.490196  ...         0.072      0.733191      0.125641
# ...        ...       ...  ...           ...           ...           ...
# 7281  0.166667  0.176471  ...         0.262      0.288154      0.484615
# 7282  0.523810  0.549020  ...         0.054      0.138741      0.139744
# 7283  0.666667  0.647059  ...         0.062      0.068303      0.065385
# 7284  0.095238  0.098039  ...         0.117      0.200640      0.174359
# 7285  0.238095  0.235294  ...         0.060      0.288154      0.139744
#
#       ortg_max_opp  drtg_max_opp  total_opp  home_opp    won  team  season
# 0         0.502488      0.256098   0.523256       1.0  False   NYK    2017
# 1         0.268657      0.548780   0.186047       0.0   True   CLE    2017
# 2         0.601990      0.487805   0.476744       1.0  False   UTA    2017
# 3         0.815920      0.390244   0.662791       0.0  False   GSW    2017
# 4         0.199005      0.768293   0.325581       1.0   True   SAS    2017
# ...            ...           ...        ...       ...    ...   ...     ...
# 7281      0.527363      0.560976   0.441860       1.0  False   MIA    2023
# 7282      0.323383      0.597561   0.372093       0.0  False   MIA    2023
# 7283      0.194030      0.536585   0.360465       1.0   True   BOS    2023
# 7284      0.820896      0.500000   0.139535       1.0   True   MIA    2023
# 7285      0.273632      0.280488   0.360465       0.0  False   BOS    2023
#
# [7286 rows x 142 columns]

# %%
rolling_cols = [f"{col}_10" for col in df_rolling.columns]
df_rolling.columns = rolling_cols

df = pd.concat([df, df_rolling], axis=1)

# %%
df
# Out:
#        mp  mp.1        fg       fga       fg%        3p       3pa       3p%  \
# 0     0.0   0.0  0.261905  0.413793  0.236842  0.285714  0.307692  0.399135
# 1     0.0   0.0  0.571429  0.534483  0.502392  0.428571  0.461538  0.453890
# 2     0.0   0.0  0.452381  0.327586  0.523923  0.250000  0.250000  0.399135
# 3     0.0   0.0  0.452381  0.379310  0.483254  0.214286  0.423077  0.224784
# 4     0.0   0.0  0.619048  0.603448  0.504785  0.392857  0.250000  0.639769
# ...   ...   ...       ...       ...       ...       ...       ...       ...
# 7281  0.0   0.0  0.452381  0.258621  0.583732  0.285714  0.230769  0.482709
# 7282  0.0   0.0  0.285714  0.517241  0.205742  0.464286  0.365385  0.592219
# 7283  0.0   0.0  0.309524  0.258621  0.399522  0.214286  0.461538  0.207493
# 7284  0.0   0.0  0.500000  0.396552  0.523923  0.464286  0.326923  0.639769
# 7285  0.0   0.0  0.261905  0.327586  0.289474  0.285714  0.596154  0.227666
#
#             ft       fta  ...  blk%_max_opp_10  tov%_max_opp_10  \
# 0     0.333333  0.372549  ...            0.144         0.644610
# 1     0.309524  0.352941  ...            0.106         0.466382
# 2     0.357143  0.294118  ...            0.051         0.466382
# 3     0.285714  0.333333  ...            0.111         1.000000
# 4     0.523810  0.490196  ...            0.072         0.733191
# ...        ...       ...  ...              ...              ...
# 7281  0.166667  0.176471  ...            0.262         0.288154
# 7282  0.523810  0.549020  ...            0.054         0.138741
# 7283  0.666667  0.647059  ...            0.062         0.068303
# 7284  0.095238  0.098039  ...            0.117         0.200640
# 7285  0.238095  0.235294  ...            0.060         0.288154
#
#       usg%_max_opp_10  ortg_max_opp_10  drtg_max_opp_10  total_opp_10  \
# 0            0.189744         0.502488         0.256098      0.523256
# 1            0.189744         0.268657         0.548780      0.186047
# 2            0.220513         0.601990         0.487805      0.476744
# 3            0.182051         0.815920         0.390244      0.662791
# 4            0.125641         0.199005         0.768293      0.325581
# ...               ...              ...              ...           ...
# 7281         0.484615         0.527363         0.560976      0.441860
# 7282         0.139744         0.323383         0.597561      0.372093
# 7283         0.065385         0.194030         0.536585      0.360465
# 7284         0.174359         0.820896         0.500000      0.139535
# 7285         0.139744         0.273632         0.280488      0.360465
#
#       home_opp_10  won_10  team_10  season_10
# 0             1.0   False      NYK       2017
# 1             0.0    True      CLE       2017
# 2             1.0   False      UTA       2017
# 3             0.0   False      GSW       2017
# 4             1.0    True      SAS       2017
# ...           ...     ...      ...        ...
# 7281          1.0   False      MIA       2023
# 7282          0.0   False      MIA       2023
# 7283          1.0    True      BOS       2023
# 7284          1.0    True      MIA       2023
# 7285          0.0   False      BOS       2023
#
# [7286 rows x 287 columns]

# %%
df = df.dropna()

# %%
df
# Out:
#        mp  mp.1        fg       fga       fg%        3p       3pa       3p%  \
# 0     0.0   0.0  0.261905  0.413793  0.236842  0.285714  0.307692  0.399135
# 1     0.0   0.0  0.571429  0.534483  0.502392  0.428571  0.461538  0.453890
# 2     0.0   0.0  0.452381  0.327586  0.523923  0.250000  0.250000  0.399135
# 3     0.0   0.0  0.452381  0.379310  0.483254  0.214286  0.423077  0.224784
# 4     0.0   0.0  0.619048  0.603448  0.504785  0.392857  0.250000  0.639769
# ...   ...   ...       ...       ...       ...       ...       ...       ...
# 7281  0.0   0.0  0.452381  0.258621  0.583732  0.285714  0.230769  0.482709
# 7282  0.0   0.0  0.285714  0.517241  0.205742  0.464286  0.365385  0.592219
# 7283  0.0   0.0  0.309524  0.258621  0.399522  0.214286  0.461538  0.207493
# 7284  0.0   0.0  0.500000  0.396552  0.523923  0.464286  0.326923  0.639769
# 7285  0.0   0.0  0.261905  0.327586  0.289474  0.285714  0.596154  0.227666
#
#             ft       fta  ...  blk%_max_opp_10  tov%_max_opp_10  \
# 0     0.333333  0.372549  ...            0.144         0.644610
# 1     0.309524  0.352941  ...            0.106         0.466382
# 2     0.357143  0.294118  ...            0.051         0.466382
# 3     0.285714  0.333333  ...            0.111         1.000000
# 4     0.523810  0.490196  ...            0.072         0.733191
# ...        ...       ...  ...              ...              ...
# 7281  0.166667  0.176471  ...            0.262         0.288154
# 7282  0.523810  0.549020  ...            0.054         0.138741
# 7283  0.666667  0.647059  ...            0.062         0.068303
# 7284  0.095238  0.098039  ...            0.117         0.200640
# 7285  0.238095  0.235294  ...            0.060         0.288154
#
#       usg%_max_opp_10  ortg_max_opp_10  drtg_max_opp_10  total_opp_10  \
# 0            0.189744         0.502488         0.256098      0.523256
# 1            0.189744         0.268657         0.548780      0.186047
# 2            0.220513         0.601990         0.487805      0.476744
# 3            0.182051         0.815920         0.390244      0.662791
# 4            0.125641         0.199005         0.768293      0.325581
# ...               ...              ...              ...           ...
# 7281         0.484615         0.527363         0.560976      0.441860
# 7282         0.139744         0.323383         0.597561      0.372093
# 7283         0.065385         0.194030         0.536585      0.360465
# 7284         0.174359         0.820896         0.500000      0.139535
# 7285         0.139744         0.273632         0.280488      0.360465
#
#       home_opp_10  won_10  team_10  season_10
# 0             1.0   False      NYK       2017
# 1             0.0    True      CLE       2017
# 2             1.0   False      UTA       2017
# 3             0.0   False      GSW       2017
# 4             1.0    True      SAS       2017
# ...           ...     ...      ...        ...
# 7281          1.0   False      MIA       2023
# 7282          0.0   False      MIA       2023
# 7283          1.0    True      BOS       2023
# 7284          1.0    True      MIA       2023
# 7285          0.0   False      BOS       2023
#
# [7286 rows x 287 columns]

# %%
def shift_col(team, col_name):
    next_col = team[col_name].shift(-1)
    return next_col

def add_col(df, col_name):
    return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))

df["home_next"] = add_col(df, "home")
df["team_opp_next"] = add_col(df, "team_opp")
df["date_next"] = add_col(df, "date")
# Out:
# /var/folders/jn/kjpxydnn7mv7lk9_v6glkk_h0000gn/T/ipykernel_35107/1688004556.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))
# /var/folders/jn/kjpxydnn7mv7lk9_v6glkk_h0000gn/T/ipykernel_35107/1688004556.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))
# /var/folders/jn/kjpxydnn7mv7lk9_v6glkk_h0000gn/T/ipykernel_35107/1688004556.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))

# %%
df
# Out:
#        mp  mp.1        fg       fga       fg%        3p       3pa       3p%  \
# 0     0.0   0.0  0.261905  0.413793  0.236842  0.285714  0.307692  0.399135
# 1     0.0   0.0  0.571429  0.534483  0.502392  0.428571  0.461538  0.453890
# 2     0.0   0.0  0.452381  0.327586  0.523923  0.250000  0.250000  0.399135
# 3     0.0   0.0  0.452381  0.379310  0.483254  0.214286  0.423077  0.224784
# 4     0.0   0.0  0.619048  0.603448  0.504785  0.392857  0.250000  0.639769
# ...   ...   ...       ...       ...       ...       ...       ...       ...
# 7281  0.0   0.0  0.452381  0.258621  0.583732  0.285714  0.230769  0.482709
# 7282  0.0   0.0  0.285714  0.517241  0.205742  0.464286  0.365385  0.592219
# 7283  0.0   0.0  0.309524  0.258621  0.399522  0.214286  0.461538  0.207493
# 7284  0.0   0.0  0.500000  0.396552  0.523923  0.464286  0.326923  0.639769
# 7285  0.0   0.0  0.261905  0.327586  0.289474  0.285714  0.596154  0.227666
#
#             ft       fta  ...  ortg_max_opp_10  drtg_max_opp_10  total_opp_10  \
# 0     0.333333  0.372549  ...         0.502488         0.256098      0.523256
# 1     0.309524  0.352941  ...         0.268657         0.548780      0.186047
# 2     0.357143  0.294118  ...         0.601990         0.487805      0.476744
# 3     0.285714  0.333333  ...         0.815920         0.390244      0.662791
# 4     0.523810  0.490196  ...         0.199005         0.768293      0.325581
# ...        ...       ...  ...              ...              ...           ...
# 7281  0.166667  0.176471  ...         0.527363         0.560976      0.441860
# 7282  0.523810  0.549020  ...         0.323383         0.597561      0.372093
# 7283  0.666667  0.647059  ...         0.194030         0.536585      0.360465
# 7284  0.095238  0.098039  ...         0.820896         0.500000      0.139535
# 7285  0.238095  0.235294  ...         0.273632         0.280488      0.360465
#
#       home_opp_10  won_10  team_10  season_10  home_next  team_opp_next  \
# 0             1.0   False      NYK       2017        1.0            MEM
# 1             0.0    True      CLE       2017        0.0            TOR
# 2             1.0   False      UTA       2017        1.0            LAL
# 3             0.0   False      GSW       2017        0.0            NOP
# 4             1.0    True      SAS       2017        0.0            SAC
# ...           ...     ...      ...        ...        ...            ...
# 7281          1.0   False      MIA       2023        1.0            BOS
# 7282          0.0   False      MIA       2023        0.0            BOS
# 7283          1.0    True      BOS       2023        1.0            MIA
# 7284          1.0    True      MIA       2023        NaN           None
# 7285          0.0   False      BOS       2023        NaN           None
#
#        date_next
# 0     2016-10-29
# 1     2016-10-28
# 2     2016-10-28
# 3     2016-10-28
# 4     2016-10-27
# ...          ...
# 7281  2023-05-27
# 7282  2023-05-29
# 7283  2023-05-29
# 7284        None
# 7285        None
#
# [7286 rows x 290 columns]

# %%
df = df.copy()

# %%
full = df.merge(df[rolling_cols + ["team_opp_next", "date_next", "team"]], 
                left_on=["team", "date_next"],
                right_on=["team_opp_next", "date_next"])

# %%
full
# Out:
#        mp  mp.1        fg       fga       fg%        3p       3pa       3p%  \
# 0     0.0   0.0  0.261905  0.413793  0.236842  0.285714  0.307692  0.399135
# 1     0.0   0.0  0.571429  0.534483  0.502392  0.428571  0.461538  0.453890
# 2     0.0   0.0  0.452381  0.327586  0.523923  0.250000  0.250000  0.399135
# 3     0.0   0.0  0.452381  0.379310  0.483254  0.214286  0.423077  0.224784
# 4     0.0   0.0  0.619048  0.603448  0.504785  0.392857  0.250000  0.639769
# ...   ...   ...       ...       ...       ...       ...       ...       ...
# 7249  0.0   0.0  0.523810  0.362069  0.581340  0.607143  0.653846  0.495677
# 7250  0.0   0.0  0.452381  0.275862  0.566986  0.535714  0.538462  0.510086
# 7251  0.0   0.0  0.452381  0.258621  0.583732  0.285714  0.230769  0.482709
# 7252  0.0   0.0  0.285714  0.517241  0.205742  0.464286  0.365385  0.592219
# 7253  0.0   0.0  0.309524  0.258621  0.399522  0.214286  0.461538  0.207493
#
#             ft       fta  ...  usg%_max_opp_10_y  ortg_max_opp_10_y  \
# 0     0.333333  0.372549  ...           0.082051           0.189055
# 1     0.309524  0.352941  ...           0.217949           0.353234
# 2     0.357143  0.294118  ...           0.206410           0.597015
# 3     0.285714  0.333333  ...           0.042308           0.253731
# 4     0.523810  0.490196  ...           0.144872           0.432836
# ...        ...       ...  ...                ...                ...
# 7249  0.261905  0.333333  ...           0.750000           0.611940
# 7250  0.309524  0.352941  ...           0.484615           0.527363
# 7251  0.166667  0.176471  ...           0.173077           0.368159
# 7252  0.523810  0.549020  ...           0.065385           0.194030
# 7253  0.666667  0.647059  ...           0.139744           0.323383
#
#       drtg_max_opp_10_y  total_opp_10_y  home_opp_10_y  won_10_y  team_10_y  \
# 0              0.475610        0.302326            0.0      True        MEM
# 1              0.524390        0.220930            0.0      True        TOR
# 2              0.597561        0.488372            0.0      True        LAL
# 3              0.268293        0.406977            0.0     False        NOP
# 4              0.524390        0.255814            1.0      True        SAC
# ...                 ...             ...            ...       ...        ...
# 7249           0.463415        0.511628            0.0     False        MIA
# 7250           0.560976        0.441860            1.0     False        MIA
# 7251           0.731707        0.290698            0.0      True        BOS
# 7252           0.536585        0.360465            1.0      True        BOS
# 7253           0.597561        0.372093            0.0     False        MIA
#
#       season_10_y  team_opp_next_y  team_y
# 0            2017              NYK     MEM
# 1            2017              CLE     TOR
# 2            2017              UTA     LAL
# 3            2017              GSW     NOP
# 4            2017              SAS     SAC
# ...           ...              ...     ...
# 7249         2023              BOS     MIA
# 7250         2023              BOS     MIA
# 7251         2023              MIA     BOS
# 7252         2023              MIA     BOS
# 7253         2023              BOS     MIA
#
# [7254 rows x 434 columns]

# %%
full[["team_x", "team_opp_next_x", "team_y", "team_opp_next_y", "date_next"]]
# Out:
#      team_x team_opp_next_x team_y team_opp_next_y   date_next
# 0       NYK             MEM    MEM             NYK  2016-10-29
# 1       CLE             TOR    TOR             CLE  2016-10-28
# 2       UTA             LAL    LAL             UTA  2016-10-28
# 3       GSW             NOP    NOP             GSW  2016-10-28
# 4       SAS             SAC    SAC             SAS  2016-10-27
# ...     ...             ...    ...             ...         ...
# 7249    BOS             MIA    MIA             BOS  2023-05-25
# 7250    BOS             MIA    MIA             BOS  2023-05-27
# 7251    MIA             BOS    BOS             MIA  2023-05-27
# 7252    MIA             BOS    BOS             MIA  2023-05-29
# 7253    BOS             MIA    MIA             BOS  2023-05-29
#
# [7254 rows x 5 columns]

# %%
removed_columns = list(full.columns[full.dtypes == "object"]) + removed_columns

# %%
removed_columns
# Out:
# ['team_x',
#  'team_opp',
#  'date',
#  'team_10_x',
#  'team_opp_next_x',
#  'date_next',
#  'team_10_y',
#  'team_opp_next_y',
#  'team_y',
#  'season',
#  'date',
#  'won',
#  'target',
#  'team',
#  'team_opp']

# %%
selected_columns = full.columns[~full.columns.isin(removed_columns)]

# %%
sfs.fit(full[selected_columns], full["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['3p%',
#  'orb%',
#  'usg%',
#  'fg_max',
#  'fta_max',
#  'gmsc_max',
#  'ortg_max',
#  'ft%_opp',
#  'stl_opp',
#  'usg%_opp',
#  'trb_max_opp',
#  'trb%_max_opp',
#  '3p%_10_x',
#  'usg%_10_x',
#  'fg_max_10_x',
#  'fta_max_10_x',
#  'gmsc_max_10_x',
#  'ortg_max_10_x',
#  'ft%_opp_10_x',
#  'stl_opp_10_x',
#  'usg%_opp_10_x',
#  'trb_max_opp_10_x',
#  'trb%_max_opp_10_x',
#  'home_next',
#  '3p%_10_y',
#  'ast%_10_y',
#  'usg%_10_y',
#  'gmsc_max_10_y',
#  'usg%_opp_10_y',
#  'ft%_max_opp_10_y']

# %%
predictions = backtest(full, rr, predictors)

# %%
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.5774260151410874
